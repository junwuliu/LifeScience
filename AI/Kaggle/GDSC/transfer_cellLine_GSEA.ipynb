# %%
import pandas as pd

# %%
head= pd.read_csv('/public/home/liujunwu/workdir/DataSets/Kaggle/GDSC/GSEA/header',sep=',',header=None)
Exp = pd.read_csv('/public/home/liujunwu/workdir/DataSets/Kaggle/GDSC/GSEA/xaa',sep=',',header=None)
Exp.columns = head.T[0]
#Exp.rename(columns={'Unnamed: 0': 'GeneSymbol'}, inplace=True)
#Exp.set_index('GeneSymbol',inplace=True)
Exp.head()
# Out:
# 0     GeneSymbol    A1BG  A1BG-AS1    A1CF     A2M  A2M-AS1   A2ML1  \
# 0          MEC-1  3.8530    1.8156  0.0000  0.2388   0.0000  0.0000
# 1        NBsusSR  4.5059    2.3868  0.0286  0.5753   0.3448  0.4751
# 2            M14  3.9736    3.1408  0.0144  4.1326   0.4114  0.0000
# 3  MDA-MB-134-VI  5.7038    3.3334  0.0566  0.5261   1.4489  0.4114
# 4          MCC26  3.9069    2.5801  0.0426  5.6562   0.5656  0.1506
#
# 0  A2ML1-AS1  A2ML1-AS2   A2MP1  ...   ZWINT    ZXDA    ZXDB    ZXDC  ZYG11A  \
# 0        0.0        0.0  0.0000  ...  6.9332  0.7655  1.9561  2.8992  0.8953
# 1        0.0        0.0  0.0144  ...  6.1613  1.7137  2.6803  5.6156  0.8480
# 2        0.0        0.0  0.0000  ...  7.6785  1.0909  2.1010  4.0488  2.6369
# 3        0.0        0.0  0.0426  ...  7.0300  1.7093  2.2570  4.3111  1.0909
# 4        0.0        0.0  0.0286  ...  6.4819  1.4005  2.3533  3.9551  2.9800
#
# 0  ZYG11AP1  ZYG11B     ZYX   ZZEF1    ZZZ3
# 0    0.0000  1.9260  4.1562  3.0959  3.6792
# ...

# %%
Exp.head()

# %%
Transpose.columns

# %%
#Exp.set_index('GeneSymbol',inplace=True)
Transpose = Exp.T
Transpose.insert(0, 'Sample', Transpose.index)
Transpose.head()
# Out:
# GeneSymbol    Sample   MEC-1  NBsusSR     M14  MDA-MB-134-VI   MCC26   MCC13  \
# A1BG            A1BG  3.8530   4.5059  3.9736         5.7038  3.9069  6.1198
# A1BG-AS1    A1BG-AS1  1.8156   2.3868  3.1408         3.3334  2.5801  3.5336
# A1CF            A1CF  0.0000   0.0286  0.0144         0.0566  0.0426  0.0144
# A2M              A2M  0.2388   0.5753  4.1326         0.5261  5.6562  0.0976
# A2M-AS1      A2M-AS1  0.0000   0.3448  0.4114         1.4489  0.5656  0.6599
#
# GeneSymbol    MCAS  MC-1010  Malme-3M  ...  JHU-011   G-MEL  CFPAC-1  \
# A1BG        0.0566   4.5638    5.1961  ...   1.0144  5.3291   0.1506
# A1BG-AS1    0.0976   3.1875    3.5570  ...   2.0321  2.5945   0.0286
# A1CF        0.0426   0.0144    0.0000  ...   0.0144  0.0000   0.0841
# A2M         0.0976   0.0841    7.6094  ...   0.0000  3.8278   0.2016
# A2M-AS1     0.0286   0.0286    1.5656  ...   0.2265  0.0976   0.3561
#
# GeneSymbol  CCF-STTG1  BxPC-3  HOP-62  HOP-92  Hs-578-T   HT-29  NCI-H3122
# ...

# %%
Transpose.to_csv('/public/home/liujunwu/workdir/DataSets/Kaggle/GDSC/GSEA/xaa.tmp',sep='\t',index=False,header=True)
